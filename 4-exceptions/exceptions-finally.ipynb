# %%
def get_inverse(x):
    try:
        return 1 / x
    except ZeroDivisionError:
        return None
    finally:
        print('I am always printed!')

# %%
print(get_inverse(2))
# Out:
# I am always printed!
# 0.5

# %%
print(get_inverse(0))
# Out:
# I am always printed!
# None

# %%
print(get_inverse('one'))
# Out:
# I am always printed!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(get_inverse('one'))
#
# Cell In[2], line 3, in get_inverse(x)
#       1 def get_inverse(x):
#       2     try:
# ----> 3         return 1 / x
#       4     except ZeroDivisionError:
#       5         return None
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
