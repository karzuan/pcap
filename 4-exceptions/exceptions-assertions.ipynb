# %%
def calculate_inverse(number):
  assert (number != 0), 'Got 0 as number!'
  return 1/number

calculate_inverse(0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 5
#       2   assert (number != 0), 'Got 0 as number!'
#       3   return 1/number
# ----> 5 calculate_inverse(0)
#
# Cell In[5], line 2, in calculate_inverse(number)
#       1 def calculate_inverse(number):
# ----> 2   assert (number != 0), 'Got 0 as number!'
#       3   return 1/number
#
# AssertionError: Got 0 as number!
